# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup
url = 'https://www.worldometers.info/coronavirus/'
req = requests.get(url)
page = BeautifulSoup(req.content,'html.parser')
table = page.find_all('table', id="main_table_countries_today")[0]
df = pd.read_html(str(table), displayed_only=False)[0]
df
# Out:
#       # Country, Other  Total Cases  New Cases  Total Deaths  New Deaths  \
# 0   NaN  North America    130661521        NaN     1667890.0         NaN
# 1   NaN           Asia    221369606        NaN     1552639.0         NaN
# 2   NaN         Europe    252938203        NaN     2095607.0         NaN
# 3   NaN  South America     69567479        NaN     1364659.0         NaN
# 4   NaN        Oceania     14723934        NaN       32189.0         NaN
# ..   ..            ...          ...        ...           ...         ...
# 242 NaN         Total:     69567479        NaN     1364659.0         NaN
# 243 NaN         Total:     14723934        NaN       32189.0         NaN
# 244 NaN         Total:     12858372        NaN      258878.0         NaN
# 245 NaN         Total:          721        NaN          15.0         NaN
# 246 NaN         Total:    702119836        0.0     6971877.0         0.0
#
#      Total Recovered  New Recovered  Active Cases  Serious, Critical  ...  \
# 0        126081026.0         1500.0     2912605.0             7670.0  ...
# 1        205498446.0         8499.0    14318521.0            14765.0  ...
# 2        248239760.0         2371.0     2602836.0             4615.0  ...
# 3         66596108.0            NaN     1606712.0             8953.0  ...
# 4         14540424.0            NaN      151321.0               55.0  ...
# ..               ...            ...           ...                ...  ...
# 242       66596108.0            NaN     1606712.0             8953.0  ...
# 243       14540424.0            NaN      151321.0               55.0  ...
# 244       12089889.0            NaN      509605.0              529.0  ...
# 245            706.0            NaN           0.0                0.0  ...
# 246      673046359.0        12370.0    22101600.0            36587.0  ...
#
#      Total Tests  Tests/ 1M pop  Population          Continent  \
# 0            NaN            NaN         NaN      North America
# 1            NaN            NaN         NaN               Asia
# 2            NaN            NaN         NaN             Europe
# 3            NaN            NaN         NaN      South America
# 4            NaN            NaN         NaN  Australia/Oceania
# ..           ...            ...         ...                ...
# 242          NaN            NaN         NaN      South America
# 243          NaN            NaN         NaN  Australia/Oceania
# 244          NaN            NaN         NaN             Africa
# 245          NaN            NaN         NaN                NaN
# 246          NaN            NaN         NaN                All
#
#      1 Case every X ppl 1 Death every X ppl  1 Test every X ppl  \
# 0                   NaN                 NaN                 NaN
# 1                   NaN                 NaN                 NaN
# 2                   NaN                 NaN                 NaN
# 3                   NaN                 NaN                 NaN
# 4                   NaN                 NaN                 NaN
# ..                  ...                 ...                 ...
# 242                 NaN                 NaN                 NaN
# 243                 NaN                 NaN                 NaN
# 244                 NaN                 NaN                 NaN
# 245                 NaN                 NaN                 NaN
# 246                 NaN                 NaN                 NaN
#
#      New Cases/1M pop  New Deaths/1M pop  Active Cases/1M pop
# 0                 NaN                NaN                  NaN
# 1                 NaN                NaN                  NaN
# 2                 NaN                NaN                  NaN
# 3                 NaN                NaN                  NaN
# 4                 NaN                NaN                  NaN
# ..                ...                ...                  ...
# 242               NaN                NaN                  NaN
# 243               NaN                NaN                  NaN
# 244               NaN                NaN                  NaN
# 245               NaN                NaN                  NaN
# 246               NaN                NaN                  NaN
#
# [247 rows x 22 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 247 entries, 0 to 246
# Data columns (total 22 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   #                    231 non-null    float64
#  1   Country, Other       246 non-null    object
#  2   Total Cases          247 non-null    int64
#  3   New Cases            2 non-null      float64
#  4   Total Deaths         242 non-null    float64
#  5   New Deaths           2 non-null      float64
#  6   Total Recovered      198 non-null    float64
#  7   New Recovered        16 non-null     float64
#  8   Active Cases         199 non-null    float64
#  9   Serious, Critical    68 non-null     float64
#  10  Tot Cases/ 1M pop    231 non-null    float64
#  11  Deaths/ 1M pop       226 non-null    float64
#  12  Total Tests          213 non-null    float64
#  13  Tests/ 1M pop        213 non-null    float64
#  14  Population           229 non-null    float64
#  15  Continent            243 non-null    object
#  16  1 Case every X ppl   229 non-null    float64
#  17  1 Death every X ppl  224 non-null    float64
#  18  1 Test every X ppl   213 non-null    float64
#  19  New Cases/1M pop     0 non-null      float64
#  20  New Deaths/1M pop    0 non-null      float64
#  21  Active Cases/1M pop  204 non-null    float64
# dtypes: float64(19), int64(1), object(2)
# memory usage: 42.6+ KB

# %%
df.shape
# Out:
# (247, 22)

# %%
df.size
# Out:
# 5434

# %%
df.head()
# Out:
#     # Country, Other  Total Cases  New Cases  Total Deaths  New Deaths  \
# 0 NaN  North America    130661521        NaN     1667890.0         NaN
# 1 NaN           Asia    221369606        NaN     1552639.0         NaN
# 2 NaN         Europe    252938203        NaN     2095607.0         NaN
# 3 NaN  South America     69567479        NaN     1364659.0         NaN
# 4 NaN        Oceania     14723934        NaN       32189.0         NaN
#
#    Total Recovered  New Recovered  Active Cases  Serious, Critical  ...  \
# 0      126081026.0         1500.0     2912605.0             7670.0  ...
# 1      205498446.0         8499.0    14318521.0            14765.0  ...
# 2      248239760.0         2371.0     2602836.0             4615.0  ...
# 3       66596108.0            NaN     1606712.0             8953.0  ...
# 4       14540424.0            NaN      151321.0               55.0  ...
#
#    Total Tests  Tests/ 1M pop  Population          Continent  \
# 0          NaN            NaN         NaN      North America
# 1          NaN            NaN         NaN               Asia
# 2          NaN            NaN         NaN             Europe
# 3          NaN            NaN         NaN      South America
# 4          NaN            NaN         NaN  Australia/Oceania
#
#    1 Case every X ppl 1 Death every X ppl  1 Test every X ppl  \
# 0                 NaN                 NaN                 NaN
# 1                 NaN                 NaN                 NaN
# 2                 NaN                 NaN                 NaN
# 3                 NaN                 NaN                 NaN
# 4                 NaN                 NaN                 NaN
#
#    New Cases/1M pop  New Deaths/1M pop  Active Cases/1M pop
# 0               NaN                NaN                  NaN
# 1               NaN                NaN                  NaN
# 2               NaN                NaN                  NaN
# 3               NaN                NaN                  NaN
# 4               NaN                NaN                  NaN
#
# [5 rows x 22 columns]

# %%
df.tail(10)
# Out:
#          # Country, Other  Total Cases  New Cases  Total Deaths  New Deaths  \
# 237  230.0     MS Zaandam            9        NaN           2.0         NaN
# 238  231.0          China       503302        NaN        5272.0         NaN
# 239    NaN         Total:    130661521        NaN     1667890.0         NaN
# 240    NaN         Total:    221369606        NaN     1552639.0         NaN
# 241    NaN         Total:    252938203        NaN     2095607.0         NaN
# 242    NaN         Total:     69567479        NaN     1364659.0         NaN
# 243    NaN         Total:     14723934        NaN       32189.0         NaN
# 244    NaN         Total:     12858372        NaN      258878.0         NaN
# 245    NaN         Total:          721        NaN          15.0         NaN
# 246    NaN         Total:    702119836        0.0     6971877.0         0.0
#
#      Total Recovered  New Recovered  Active Cases  Serious, Critical  ...  \
# 237              7.0            NaN           0.0                NaN  ...
# 238         379053.0            NaN      118977.0                NaN  ...
# 239      126081026.0            NaN     2912605.0             7670.0  ...
# 240      205498446.0            NaN    14318521.0            14765.0  ...
# 241      248239760.0            NaN     2602836.0             4615.0  ...
# 242       66596108.0            NaN     1606712.0             8953.0  ...
# 243       14540424.0            NaN      151321.0               55.0  ...
# 244       12089889.0            NaN      509605.0              529.0  ...
# 245            706.0            NaN           0.0                0.0  ...
# 246      673046359.0        12370.0    22101600.0            36587.0  ...
#
#      Total Tests  Tests/ 1M pop    Population          Continent  \
# 237          NaN            NaN           NaN                NaN
# 238  160000000.0       110461.0  1.448471e+09               Asia
# 239          NaN            NaN           NaN      North America
# 240          NaN            NaN           NaN               Asia
# 241          NaN            NaN           NaN             Europe
# 242          NaN            NaN           NaN      South America
# 243          NaN            NaN           NaN  Australia/Oceania
# 244          NaN            NaN           NaN             Africa
# 245          NaN            NaN           NaN                NaN
# 246          NaN            NaN           NaN                All
#
#      1 Case every X ppl 1 Death every X ppl  1 Test every X ppl  \
# 237                 NaN                 NaN                 NaN
# 238              2878.0            274748.0                 9.0
# 239                 NaN                 NaN                 NaN
# 240                 NaN                 NaN                 NaN
# 241                 NaN                 NaN                 NaN
# 242                 NaN                 NaN                 NaN
# 243                 NaN                 NaN                 NaN
# 244                 NaN                 NaN                 NaN
# 245                 NaN                 NaN                 NaN
# 246                 NaN                 NaN                 NaN
#
#      New Cases/1M pop  New Deaths/1M pop  Active Cases/1M pop
# 237               NaN                NaN                  NaN
# 238               NaN                NaN                 82.0
# 239               NaN                NaN                  NaN
# 240               NaN                NaN                  NaN
# 241               NaN                NaN                  NaN
# 242               NaN                NaN                  NaN
# 243               NaN                NaN                  NaN
# 244               NaN                NaN                  NaN
# 245               NaN                NaN                  NaN
# 246               NaN                NaN                  NaN
#
# [10 rows x 22 columns]

# %%
df.isnull().sum()
# Out:
# #                       16
# Country, Other           1
# Total Cases              0
# New Cases              245
# Total Deaths             5
# New Deaths             245
# Total Recovered         49
# New Recovered          231
# Active Cases            48
# Serious, Critical      179
# Tot Cases/ 1M pop       16
# Deaths/ 1M pop          21
# Total Tests             34
# Tests/ 1M pop           34
# Population              18
# Continent                4
# 1 Case every X ppl      18
# 1 Death every X ppl     23
# 1 Test every X ppl      34
# New Cases/1M pop       247
# New Deaths/1M pop      247
# Active Cases/1M pop     43
# dtype: int64

# %%
df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 242    False
# 243    False
# 244    False
# 245    False
# 246    False
# Length: 247, dtype: bool

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
dff = df.drop(columns=['New Cases','#','New Deaths','New Recovered','Serious, Critical','New Cases/1M pop','New Deaths/1M pop'])
dff.head()
# Out:
#   Country, Other  Total Cases  Total Deaths  Total Recovered  Active Cases  \
# 0  North America    130661521     1667890.0      126081026.0     2912605.0
# 1           Asia    221369606     1552639.0      205498446.0    14318521.0
# 2         Europe    252938203     2095607.0      248239760.0     2602836.0
# 3  South America     69567479     1364659.0       66596108.0     1606712.0
# 4        Oceania     14723934       32189.0       14540424.0      151321.0
#
#    Tot Cases/ 1M pop  Deaths/ 1M pop  Total Tests  Tests/ 1M pop  Population  \
# 0                NaN             NaN          NaN            NaN         NaN
# 1                NaN             NaN          NaN            NaN         NaN
# 2                NaN             NaN          NaN            NaN         NaN
# 3                NaN             NaN          NaN            NaN         NaN
# 4                NaN             NaN          NaN            NaN         NaN
#
#            Continent  1 Case every X ppl  1 Death every X ppl  \
# 0      North America                 NaN                  NaN
# 1               Asia                 NaN                  NaN
# 2             Europe                 NaN                  NaN
# 3      South America                 NaN                  NaN
# 4  Australia/Oceania                 NaN                  NaN
#
#    1 Test every X ppl  Active Cases/1M pop
# 0                 NaN                  NaN
# 1                 NaN                  NaN
# 2                 NaN                  NaN
# 3                 NaN                  NaN
# 4                 NaN                  NaN

# %%
dff.isnull().sum()
# Out:
# Country, Other          1
# Total Cases             0
# Total Deaths            5
# Total Recovered        49
# Active Cases           48
# Tot Cases/ 1M pop      16
# Deaths/ 1M pop         21
# Total Tests            34
# Tests/ 1M pop          34
# Population             18
# Continent               4
# 1 Case every X ppl     18
# 1 Death every X ppl    23
# 1 Test every X ppl     34
# Active Cases/1M pop    43
# dtype: int64

# %%
dff.dropna(inplace=True)

# %%
dff.isnull().sum()
# Out:
# Country, Other         0
# Total Cases            0
# Total Deaths           0
# Total Recovered        0
# Active Cases           0
# Tot Cases/ 1M pop      0
# Deaths/ 1M pop         0
# Total Tests            0
# Tests/ 1M pop          0
# Population             0
# Continent              0
# 1 Case every X ppl     0
# 1 Death every X ppl    0
# 1 Test every X ppl     0
# Active Cases/1M pop    0
# dtype: int64

# %%
#Exporting data into Excel
dff.to_csv("Corona_Dataset.csv")
